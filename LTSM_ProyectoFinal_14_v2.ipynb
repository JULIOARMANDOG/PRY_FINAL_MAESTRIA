# %% [markdown]
# <a href="https://colab.research.google.com/github/JULIOARMANDOG/PRY_FINAL_MAESTRIA/blob/main/LTSM_ProyectoFinal_14_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importando las librerías necesarias
import zipfile
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import seaborn as sns # Import seaborn
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import GridSearchCV
from collections import Counter
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout,Input
from keras.optimizers import SGD
from keras.utils import plot_model
from keras.layers import LSTM
from keras.callbacks import EarlyStopping

# CARGA DE DATOS
zip_path='uci-har.zip'
with zipfile.ZipFile(zip_path,'r') as zipRef:
  zipRef.extractall('sample_data/')

X_train_route = 'sample_data/uci-har/train/X_train.txt'
y_train_route = 'sample_data/uci-har/train/y_train.txt'

X_train = pd.read_csv(X_train_route, delim_whitespace=True, header=None)
y_train = pd.read_csv(y_train_route, delim_whitespace=True, header=None)

#NORMALIZACION DE DATOS
scaler= StandardScaler()
X_train = scaler.fit_transform(X_train)

# convertir X_train en un arreglo 3D para LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))

#Aplicar one-hot encoding a y_train
y_train = to_categorical(y_train-1)  # Restar 1 para que las clases comiencen desde 0

# Definir el modelo LSTM
model = Sequential()
model.add(LSTM(units=50, return_sequences=False, input_shape=(X_train.shape[1], X_train.shape[2]))) # Changed return_sequences to False
model.add(Dropout(0.2))
model.add(Dense(units=y_train.shape[1], activation='softmax'))
# Compilar el modelo
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Entrenar el modelo con EarlyStopping
early_stopping = EarlyStopping(monitor='loss', patience=5, verbose=1)

# Entrenar el modelo
history = model.fit(X_train, y_train, epochs=50, batch_size=32, callbacks=[early_stopping])

#imprimir el resumen del modelo
model.summary()

# Graficar la pérdida del entrenamiento
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Pérdida de entrenamiento')
plt.title('Pérdida del modelo LSTM')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.show()

#graficar la precisión del entrenamiento
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Precisión de entrenamiento')
plt.title('Precisión del modelo LSTM')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.show()

# Evaluar el modelo LSTM
X_test_route = 'sample_data/uci-har/test/X_test.txt'
y_test_route = 'sample_data/uci-har/test/y_test.txt'
X_test = pd.read_csv(X_test_route, delim_whitespace=True, header=None)
y_test = pd.read_csv(y_test_route, delim_whitespace=True, header=None)
# Normalizar los datos de prueba
X_test = scaler.transform(X_test)
# Convertir X_test en un arreglo 3D para LSTM
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
# Aplicar one-hot encoding a y_test
y_test = to_categorical(y_test-1)  # Restar 1 para que las clases comiencen desde 0
# Predecir con el modelo LSTM
y_pred = model.predict(X_test)
# Convertir las predicciones a etiquetas
y_pred_labels = np.argmax(y_pred, axis=1)
# Convertir y_test a etiquetas
y_test_labels = np.argmax(y_test, axis=1)
# Imprimir el reporte de clasificación
print(classification_report(y_test_labels, y_pred_labels))
# Imprimir la matriz de confusión
print(confusion_matrix(y_test_labels, y_pred_labels))
# Graficar la matriz de confusión
labels = ['WALKING', 'WALKING_UPSTAIRS', 'WALKING_DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING']
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test_labels, y_pred_labels), annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.title('Matriz de Confusión')
plt.xlabel('Predicción')
plt.ylabel('Realidad')
plt.show()
# Out:
# /tmp/ipython-input-4-2010068773.py:30: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   X_train = pd.read_csv(X_train_route, delim_whitespace=True, header=None)
# Epoch 1/50
# /tmp/ipython-input-4-2010068773.py:31: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   y_train = pd.read_csv(y_train_route, delim_whitespace=True, header=None)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 45s 189ms/step - accuracy: 0.4533 - loss: 1.3321
# Epoch 2/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 44s 190ms/step - accuracy: 0.6528 - loss: 0.7907
# ...
